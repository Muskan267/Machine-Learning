# %%
#Importing pandas library
import pandas as pd

# %%
#loading of file from local folder
data = pd.read_csv('aug_train.csv')
data
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
#Loading csv from any URL
url = 'https://raw.githubusercontent.com/Tanishqa-10/AskPython/main/Sampledata.csv'
data_url = pd.read_csv(url)

# %%
data_url
# Out:
#       Name Last Name Member         City Code  Amount
# 0      Jim       Doe     No         Ohio   JD    8075
# 1     Gill  McGinnis    Yes        Texas   GM    9119
# 2      Joe    Repici    Yes       Bostan   JR    8075
# 3  Stephen     Tyler     No           LA   ST   91234
# 4    Oscar  Blankman     No          NYC   OB     298
# 5    Kelly       Jet     No  Desert City   KJ     123

# %%
#sep parameter 
data_tsv = pd.read_csv('movie_titles_metadata.tsv')

# %%
data_tsv
# Out:
#     m0\t10 things i hate about you\t1999\t6.90\t62847\t['comedy' 'romance']
# 0    m1\t1492: conquest of paradise\t1992\t6.20\t10...
# 1    m2\t15 minutes\t2001\t6.10\t25854\t['action' '...
# 2    m3\t2001: a space odyssey\t1968\t8.40\t163227\...
# 3    m4\t48 hrs.\t1982\t6.90\t22289\t['action' 'com...
# 4    m5\tthe fifth element\t1997\t7.50\t133756\t['a...
# ..                                                 ...
# 611  m612\twatchmen\t2009\t7.80\t135229\t['action' ...
# 612  m613\txxx\t2002\t5.60\t53505\t['action' 'adven...
# 613  m614\tx-men\t2000\t7.40\t122149\t['action' 'sc...
# 614  m615\tyoung frankenstein\t1974\t8.00\t57618\t[...
# 615  m616\tzulu dawn\t1979\t6.40\t1911\t['action' '...
#
# [616 rows x 1 columns]

# %% [raw]
# Note : Here all the data is coming in the single column because for text.csv files we have sep=',' by default . But for tsv we don't have any seprators designed for it
# .So we will define sep param !

# %%
data_tsv = pd.read_csv('movie_titles_metadata.tsv', sep='\t')

# %%
data_tsv
# Out:
#        m0  10 things i hate about you  1999  6.90     62847  \
# 0      m1  1492: conquest of paradise  1992   6.2   10421.0
# 1      m2                  15 minutes  2001   6.1   25854.0
# 2      m3       2001: a space odyssey  1968   8.4  163227.0
# 3      m4                     48 hrs.  1982   6.9   22289.0
# 4      m5           the fifth element  1997   7.5  133756.0
# ..    ...                         ...   ...   ...       ...
# 611  m612                    watchmen  2009   7.8  135229.0
# 612  m613                         xxx  2002   5.6   53505.0
# 613  m614                       x-men  2000   7.4  122149.0
# 614  m615          young frankenstein  1974   8.0   57618.0
# 615  m616                   zulu dawn  1979   6.4    1911.0
#
#                                   ['comedy' 'romance']
# 0          ['adventure' 'biography' 'drama' 'history']
# 1                ['action' 'crime' 'drama' 'thriller']
# 2                     ['adventure' 'mystery' 'sci-fi']
# ...

# %% [raw]
# Note : In the above output we had noticed we don't have column names. the first row will considered as column names. So for that we can use 'names' parameter where we will pass a list of columnn names on basis of our understanding.

# %%
data_tsv = pd.read_csv('movie_titles_metadata.tsv', sep='\t' , names =['ID' , 'name_of_movie' , 'year' , 'ratings' , 'Votings' , 'genre'])

# %%
data_tsv
# Out:
#        ID               name_of_movie  year  ratings   Votings  \
# 0      m0  10 things i hate about you  1999      6.9   62847.0
# 1      m1  1492: conquest of paradise  1992      6.2   10421.0
# 2      m2                  15 minutes  2001      6.1   25854.0
# 3      m3       2001: a space odyssey  1968      8.4  163227.0
# 4      m4                     48 hrs.  1982      6.9   22289.0
# ..    ...                         ...   ...      ...       ...
# 612  m612                    watchmen  2009      7.8  135229.0
# 613  m613                         xxx  2002      5.6   53505.0
# 614  m614                       x-men  2000      7.4  122149.0
# 615  m615          young frankenstein  1974      8.0   57618.0
# 616  m616                   zulu dawn  1979      6.4    1911.0
#
#                                                  genre
# 0                                 ['comedy' 'romance']
# 1          ['adventure' 'biography' 'drama' 'history']
# ...

# %%
#Index col parameter 
data
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %% [raw]
# Note : here we see we have two index columns , which are not needed . So we can choose one using index_col parameter .

# %%
data = pd.read_csv('aug_train.csv' , index_col = 'enrollee_id' )
data
# Out:
#                  city  city_development_index gender      relevent_experience  \
# enrollee_id
# 8949         city_103                   0.920   Male  Has relevent experience
# 29725         city_40                   0.776   Male   No relevent experience
# 11561         city_21                   0.624    NaN   No relevent experience
# 33241        city_115                   0.789    NaN   No relevent experience
# 666          city_162                   0.767   Male  Has relevent experience
# ...               ...                     ...    ...                      ...
# 7386         city_173                   0.878   Male   No relevent experience
# 31398        city_103                   0.920   Male  Has relevent experience
# 24576        city_103                   0.920   Male  Has relevent experience
# 5756          city_65                   0.802   Male  Has relevent experience
# 23834         city_67                   0.855    NaN   No relevent experience
#
# ...

# %% [raw]
# Note : if we have column name as a first row and in column header we are seeing headers as unnamed 0 , unnamed 1 then use header=1

# %%
# use_cols parameters : you can use it to select selective columns 
data_new = pd.read_csv('aug_train.csv' ,  usecols = ['gender' , 'city'])

# %%
data_new
# Out:
#            city gender
# 0      city_103   Male
# 1       city_40   Male
# 2       city_21    NaN
# 3      city_115    NaN
# 4      city_162   Male
# ...         ...    ...
# 19153  city_173   Male
# 19154  city_103   Male
# 19155  city_103   Male
# 19156   city_65   Male
# 19157   city_67    NaN
#
# [19158 rows x 2 columns]

# %%
#Skiprows and nrows
data_new = pd.read_csv('aug_train.csv' , skiprows=[1,6])

# %%
data_new
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0            29725   city_40                   0.776   Male
# 1            11561   city_21                   0.624    NaN
# 2            33241  city_115                   0.789    NaN
# 3              666  city_162                   0.767   Male
# 4            28806  city_160                   0.920   Male
# ...            ...       ...                     ...    ...
# 19151         7386  city_173                   0.878   Male
# 19152        31398  city_103                   0.920   Male
# 19153        24576  city_103                   0.920   Male
# 19154         5756   city_65                   0.802   Male
# 19155        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0       No relevent experience       no_enrollment        Graduate
# 1       No relevent experience    Full time course        Graduate
# ...

# %%
data_new = pd.read_csv('aug_train.csv' , nrows=200)

# %%
data_new
# Out:
#      enrollee_id      city  city_development_index gender  \
# 0           8949  city_103                   0.920   Male
# 1          29725   city_40                   0.776   Male
# 2          11561   city_21                   0.624    NaN
# 3          33241  city_115                   0.789    NaN
# 4            666  city_162                   0.767   Male
# ..           ...       ...                     ...    ...
# 195         9890  city_103                   0.920   Male
# 196        32683  city_160                   0.920   Male
# 197        27104   city_36                   0.893   Male
# 198         7731   city_65                   0.802   Male
# 199        31943   city_71                   0.884   Male
#
#          relevent_experience enrolled_university education_level  \
# 0    Has relevent experience       no_enrollment        Graduate
# 1     No relevent experience       no_enrollment        Graduate
# 2     No relevent experience    Full time course        Graduate
# ...

# %% [raw]
# #Encoding parameter
# Whenever you will read a file which will throw an unicodeedcode error , it means we have encode it :
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xed in position 7044: invalid continuation byte

# %%
data_zomato = pd.read_csv('zomato.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 data_zomato = pd.read_csv('zomato.csv')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
data_zomato = pd.read_csv('zomato.csv' , encoding = 'latin-1')

# %%
data_zomato
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
#Skip bad rows  
ParserError: Error tokenizing data. C error: Expected 1 fields in line 54, saw 2
In bad rows we will get this parse error . It means in line 52 expected columns is 1 but we are seeing 2 .

# %%
data_badrows = pd.read_csv('BX-Books.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 data_badrows = pd.read_csv('BX-Books.csv')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
pd.read_csv('BX-Books.csv' ,sep=';', encoding = 'Latin-1', on_bad_lines='skip')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_20748\3617925084.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv('BX-Books.csv' ,sep=';', encoding = 'Latin-1', on_bad_lines='skip')
#         0195153448                                Classical Mythology  \
# 0       0002005018                                       Clara Callan
# 1       0060973129                               Decision in Normandy
# 2       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 3       0393045218                             The Mummies of Urumchi
# 4       0399135782                             The Kitchen God's Wife
# ...            ...                                                ...
# 271354  0440400988                         There's a Bat in Bunk Five
# 271355  0525447644                            From One to One Hundred
# 271356  006008667X  Lily Dale : The True Story of the Town that Ta...
# ...

# %%
#handling dtypes 
data = pd.read_csv('aug_train.csv')

# %%
data
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
#So in this table we can see we have target column which has two unique values only : 1, 0  and it is stored in float . Just to confirm we can check it 
#by using info()

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19158 non-null  int64
#  1   city                    19158 non-null  object
#  2   city_development_index  19158 non-null  float64
#  3   gender                  14650 non-null  object
#  4   relevent_experience     19158 non-null  object
#  5   enrolled_university     18772 non-null  object
#  6   education_level         18698 non-null  object
#  7   major_discipline        16345 non-null  object
#  8   experience              19093 non-null  object
#  9   company_size            13220 non-null  object
#  10  company_type            13018 non-null  object
#  11  last_new_job            18735 non-null  object
#  12  training_hours          19158 non-null  int64
#  13  target                  19158 non-null  float64
# ...

# %%
#Float will take more memory and it's not needed here so we will convert it into integer .
pd.read_csv('aug_train.csv' , dtype={'target': 'int32'}).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19158 non-null  int64
#  1   city                    19158 non-null  object
#  2   city_development_index  19158 non-null  float64
#  3   gender                  14650 non-null  object
#  4   relevent_experience     19158 non-null  object
#  5   enrolled_university     18772 non-null  object
#  6   education_level         18698 non-null  object
#  7   major_discipline        16345 non-null  object
#  8   experience              19093 non-null  object
#  9   company_size            13220 non-null  object
#  10  company_type            13018 non-null  object
#  11  last_new_job            18735 non-null  object
#  12  training_hours          19158 non-null  int64
#  13  target                  19158 non-null  int32
# ...

# %% [raw]
# #Handling dates
# So I don't have any specific dataset to show this dataset but yes I will explain it .
# By default while reading to csv file , date columns are readed as object(that is string) . So because of this we can't use date() in built functions to
# play around with date column . so for that we can use parse_date = ['column names']

# %% [raw]
# #Loading datasets in chunks
# So for that we can use chunk parameter . while reading the file we can use a = pd.read_csv(filename , chunk = no of rows)
#
# for i in a:
#     return chunk

# %% [raw]
# Thank you !
